# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from statsmodels.stats.outliers_influence \
import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
summarize,
poly)
from sklearn.metrics import accuracy_score
from ISLP import confusion_table
from ISLP.models import contrast
from sklearn.discriminant_analysis import \
    (LinearDiscriminantAnalysis as LDA,
     QuadraticDiscriminantAnalysis as QDA)
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import GridSearchCV

# %%
train = pd.read_csv("dataset/train.csv")
test = pd.read_csv("dataset/test.csv")

# %%
train.corr()
# Out:
#                                         ID  ...  Customer_Churn
# ID                                1.000000  ...       -0.019766
# Age                              -0.003650  ...        0.109484
# AI_Interaction_Level              0.001213  ...       -0.153978
# Satisfaction_with_AI_Services    -0.026875  ...       -0.103294
# AI_Personalization_Effectiveness -0.021246  ...       -0.098060
# AI_Response_Time                 -0.015012  ...       -0.016676
# Overall_Usage_Frequency          -0.004322  ...       -0.019843
# Customer_Service_Interactions     0.009345  ...        0.003646
# Change_in_Usage_Patterns         -0.006244  ...        0.027809
# Customer_Churn                   -0.019766  ...        1.000000
#
# [10 rows x 10 columns]

# %%
features = ["AI_Interaction_Level", "Satisfaction_with_AI_Services"]

# Selecting only the specified features for X
allvars= train[features]

design = MS(allvars)
X = design.fit_transform(train)
y = train["Customer_Churn"]
glm = sm.GLM(y,X,family=sm.families.Binomial())
results = glm.fit()
summarize(results)
# Out:
#                                  coef  std err      z  P>|z|
# intercept                      1.3657    0.282  4.846  0.000
# AI_Interaction_Level          -0.4118    0.051 -8.008  0.000
# Satisfaction_with_AI_Services -0.0776    0.010 -7.570  0.000
# Age                           -0.0062    0.004 -1.629  0.103

# %%
# Assuming you have a DataFrame `test` for which you need to make predictions
X_test = design.transform(test)  # Transform the test dataset
y_test = test["Customer_Churn"]   # Actual outcomes

# Get the predicted probabilities for the positive class (1)
predicted_probabilities = results.predict(X_test)

# Convert probabilities to binary predictions using 0.5 as the threshold
predictions = (predicted_probabilities > 0.5).astype(int)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Generate the confusion matrix
cm = confusion_matrix(y_test, predictions)

# Print the confusion matrix
print("Confusion Matrix:")
print(cm)

# Generate a classification report
report = classification_report(y_test, predictions)
print("\nClassification Report:")
print(report)
# Out:
# Confusion Matrix:
# [[589 125]
#  [409 127]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.82      0.69       714
#            1       0.50      0.24      0.32       536
#
#     accuracy                           0.57      1250
#    macro avg       0.55      0.53      0.51      1250
# weighted avg       0.55      0.57      0.53      1250

# %%
lda = LDA(store_covariance=True)

# %%
train_model = MS(["AI_Interaction_Level", "Satisfaction_with_AI_Services"]).fit(train)
test_model = MS(["AI_Interaction_Level", "Satisfaction_with_AI_Services"]).fit(test)
x_train = train_model.transform(train)
x_test = test_model.transform(test)
y_train = train["Customer_Churn"]
y_test = test["Customer_Churn"]

x_train, x_test = [M.drop(columns=['intercept']) for M in [x_train,x_test]]
lda.fit(x_train,y_train)
# Out:
# LinearDiscriminantAnalysis(store_covariance=True)

# %%
lda_pred = lda.predict(x_test)
confusion_table(lda_pred,y_test)
# Out:
# Truth        0    1
# Predicted
# 0          582  398
# 1          132  138

# %%
accuracy = accuracy_score(y_test, lda_pred)
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 57.60%

# %%
lda_prob = lda.predict_proba(x_test)
np.all(np.where(lda_prob[:,1]>=0.5,1,0)==lda_pred)
# Out:
# True

# %%
qda = QDA(store_covariance=True)
qda.fit(x_train,y_train)
# Out:
# QuadraticDiscriminantAnalysis(store_covariance=True)

# %%
qda_pred = qda.predict(x_test)
confusion_table(qda_pred,y_test)
# Out:
# Truth        0    1
# Predicted
# 0          605  416
# 1          109  120

# %%
accuracy = accuracy_score(y_test, qda_pred)
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 58.00%

# %%
NB = GaussianNB()
NB.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
nb_labels = NB.predict(x_test)
confusion_table(nb_labels,y_test)
# Out:
# Truth        0    1
# Predicted
# 0          609  416
# 1          105  120

# %%
accuracy = accuracy_score(y_test, nb_labels)
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 58.32%

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix

for K in range(1, 200):
    # Initialize and fit the K-Nearest Neighbors classifier with K neighbors
    knn = KNeighborsClassifier(n_neighbors=K)
    knn_pred = knn.fit(x_train, y_train).predict(x_test)
    
    # Generate the confusion matrix
    C = confusion_matrix(y_test, knn_pred)
    
    # Assuming binary classification, and you're interested in the positive class ('1')
    TP = C[1, 1]  # True Positives: correctly predicted as class '1'
    TN = C[0, 0]  # True Negatives: correctly predicted as class '0'
    FP = C[0, 1]  # False Positives: incorrectly predicted as class '1'
    FN = C[1, 0]  # False Negatives: incorrectly predicted as class '0'
    
    total_predicted_positive = TP + FP  # Total predicted as class '1'
    did_actually_positive = TP  # Correctly predicted as class '1'
    
    if total_predicted_positive > 0:
        accuracy_of_positive_predictions = did_actually_positive / total_predicted_positive
    else:
        accuracy_of_positive_predictions = 0  # To handle division by zero
    
    templ = ('K = {0:2d}: # predicted as positive: {1:3d}, # actually positive: {2:3d}, accuracy of positive predictions: {3:.1%}')
    print(templ.format(K, total_predicted_positive, did_actually_positive, accuracy_of_positive_predictions))
# Out:
# K =  1: # predicted as positive: 575, # actually positive: 250, accuracy of positive predictions: 43.5%
# K =  2: # predicted as positive: 238, # actually positive: 101, accuracy of positive predictions: 42.4%
# K =  3: # predicted as positive: 515, # actually positive: 241, accuracy of positive predictions: 46.8%
# K =  4: # predicted as positive: 237, # actually positive: 119, accuracy of positive predictions: 50.2%
# K =  5: # predicted as positive: 541, # actually positive: 269, accuracy of positive predictions: 49.7%
# K =  6: # predicted as positive: 238, # actually positive: 126, accuracy of positive predictions: 52.9%
# K =  7: # predicted as positive: 496, # actually positive: 267, accuracy of positive predictions: 53.8%
# K =  8: # predicted as positive: 265, # actually positive: 140, accuracy of positive predictions: 52.8%
# K =  9: # predicted as positive: 584, # actually positive: 308, accuracy of positive predictions: 52.7%
# K = 10: # predicted as positive: 438, # actually positive: 232, accuracy of positive predictions: 53.0%
# K = 11: # predicted as positive: 587, # actually positive: 308, accuracy of positive predictions: 52.5%
# K = 12: # predicted as positive: 395, # actually positive: 207, accuracy of positive predictions: 52.4%
# K = 13: # predicted as positive: 637, # actually positive: 329, accuracy of positive predictions: 51.6%
# K = 14: # predicted as positive: 505, # actually positive: 267, accuracy of positive predictions: 52.9%
# K = 15: # predicted as positive: 505, # actually positive: 267, accuracy of positive predictions: 52.9%
# K = 16: # predicted as positive: 478, # actually positive: 249, accuracy of positive predictions: 52.1%
# K = 17: # predicted as positive: 512, # actually positive: 266, accuracy of positive predictions: 52.0%
# K = 18: # predicted as positive: 495, # actually positive: 257, accuracy of positive predictions: 51.9%
# K = 19: # predicted as positive: 563, # actually positive: 297, accuracy of positive predictions: 52.8%
# K = 20: # predicted as positive: 461, # actually positive: 240, accuracy of positive predictions: 52.1%
# K = 21: # predicted as positive: 556, # actually positive: 298, accuracy of positive predictions: 53.6%
# K = 22: # predicted as positive: 534, # actually positive: 286, accuracy of positive predictions: 53.6%
# K = 23: # predicted as positive: 534, # actually positive: 286, accuracy of positive predictions: 53.6%
# K = 24: # predicted as positive: 507, # actually positive: 268, accuracy of positive predictions: 52.9%
# K = 25: # predicted as positive: 507, # actually positive: 268, accuracy of positive predictions: 52.9%
# K = 26: # predicted as positive: 483, # actually positive: 252, accuracy of positive predictions: 52.2%
# K = 27: # predicted as positive: 507, # actually positive: 268, accuracy of positive predictions: 52.9%
# K = 28: # predicted as positive: 458, # actually positive: 240, accuracy of positive predictions: 52.4%
# K = 29: # predicted as positive: 576, # actually positive: 297, accuracy of positive predictions: 51.6%
# K = 30: # predicted as positive: 548, # actually positive: 286, accuracy of positive predictions: 52.2%
# K = 31: # predicted as positive: 572, # actually positive: 302, accuracy of positive predictions: 52.8%
# K = 32: # predicted as positive: 514, # actually positive: 269, accuracy of positive predictions: 52.3%
# K = 33: # predicted as positive: 548, # actually positive: 286, accuracy of positive predictions: 52.2%
# K = 34: # predicted as positive: 514, # actually positive: 269, accuracy of positive predictions: 52.3%
# K = 35: # predicted as positive: 595, # actually positive: 303, accuracy of positive predictions: 50.9%
# K = 36: # predicted as positive: 561, # actually positive: 286, accuracy of positive predictions: 51.0%
# K = 37: # predicted as positive: 589, # actually positive: 297, accuracy of positive predictions: 50.4%
# K = 38: # predicted as positive: 589, # actually positive: 297, accuracy of positive predictions: 50.4%
# K = 39: # predicted as positive: 589, # actually positive: 297, accuracy of positive predictions: 50.4%
# K = 40: # predicted as positive: 564, # actually positive: 285, accuracy of positive predictions: 50.5%
# K = 41: # predicted as positive: 564, # actually positive: 285, accuracy of positive predictions: 50.5%
# K = 42: # predicted as positive: 479, # actually positive: 243, accuracy of positive predictions: 50.7%
# K = 43: # predicted as positive: 577, # actually positive: 294, accuracy of positive predictions: 51.0%
# K = 44: # predicted as positive: 525, # actually positive: 271, accuracy of positive predictions: 51.6%
# K = 45: # predicted as positive: 615, # actually positive: 319, accuracy of positive predictions: 51.9%
# K = 46: # predicted as positive: 577, # actually positive: 294, accuracy of positive predictions: 51.0%
# K = 47: # predicted as positive: 599, # actually positive: 305, accuracy of positive predictions: 50.9%
# K = 48: # predicted as positive: 471, # actually positive: 239, accuracy of positive predictions: 50.7%
# K = 49: # predicted as positive: 606, # actually positive: 311, accuracy of positive predictions: 51.3%
# K = 50: # predicted as positive: 478, # actually positive: 254, accuracy of positive predictions: 53.1%
# K = 51: # predicted as positive: 559, # actually positive: 288, accuracy of positive predictions: 51.5%
# K = 52: # predicted as positive: 505, # actually positive: 256, accuracy of positive predictions: 50.7%
# K = 53: # predicted as positive: 559, # actually positive: 288, accuracy of positive predictions: 51.5%
# K = 54: # predicted as positive: 559, # actually positive: 288, accuracy of positive predictions: 51.5%
# K = 55: # predicted as positive: 581, # actually positive: 299, accuracy of positive predictions: 51.5%
# K = 56: # predicted as positive: 559, # actually positive: 288, accuracy of positive predictions: 51.5%
# K = 57: # predicted as positive: 559, # actually positive: 288, accuracy of positive predictions: 51.5%
# K = 58: # predicted as positive: 483, # actually positive: 252, accuracy of positive predictions: 52.2%
# K = 59: # predicted as positive: 517, # actually positive: 269, accuracy of positive predictions: 52.0%
# K = 60: # predicted as positive: 517, # actually positive: 269, accuracy of positive predictions: 52.0%
# K = 61: # predicted as positive: 517, # actually positive: 269, accuracy of positive predictions: 52.0%
# K = 62: # predicted as positive: 446, # actually positive: 235, accuracy of positive predictions: 52.7%
# K = 63: # predicted as positive: 446, # actually positive: 235, accuracy of positive predictions: 52.7%
# K = 64: # predicted as positive: 399, # actually positive: 218, accuracy of positive predictions: 54.6%
# K = 65: # predicted as positive: 437, # actually positive: 243, accuracy of positive predictions: 55.6%
# K = 66: # predicted as positive: 418, # actually positive: 234, accuracy of positive predictions: 56.0%
# K = 67: # predicted as positive: 484, # actually positive: 260, accuracy of positive predictions: 53.7%
# K = 68: # predicted as positive: 427, # actually positive: 226, accuracy of positive predictions: 52.9%
# K = 69: # predicted as positive: 527, # actually positive: 283, accuracy of positive predictions: 53.7%
# K = 70: # predicted as positive: 423, # actually positive: 232, accuracy of positive predictions: 54.8%
# K = 71: # predicted as positive: 448, # actually positive: 244, accuracy of positive predictions: 54.5%
# K = 72: # predicted as positive: 423, # actually positive: 232, accuracy of positive predictions: 54.8%
# K = 73: # predicted as positive: 448, # actually positive: 244, accuracy of positive predictions: 54.5%
# K = 74: # predicted as positive: 423, # actually positive: 232, accuracy of positive predictions: 54.8%
# K = 75: # predicted as positive: 530, # actually positive: 285, accuracy of positive predictions: 53.8%
# K = 76: # predicted as positive: 536, # actually positive: 285, accuracy of positive predictions: 53.2%
# K = 77: # predicted as positive: 508, # actually positive: 274, accuracy of positive predictions: 53.9%
# K = 78: # predicted as positive: 470, # actually positive: 249, accuracy of positive predictions: 53.0%
# K = 79: # predicted as positive: 508, # actually positive: 274, accuracy of positive predictions: 53.9%
# K = 80: # predicted as positive: 470, # actually positive: 249, accuracy of positive predictions: 53.0%
# K = 81: # predicted as positive: 582, # actually positive: 308, accuracy of positive predictions: 52.9%
# K = 82: # predicted as positive: 492, # actually positive: 260, accuracy of positive predictions: 52.8%
# K = 83: # predicted as positive: 586, # actually positive: 302, accuracy of positive predictions: 51.5%
# K = 84: # predicted as positive: 586, # actually positive: 302, accuracy of positive predictions: 51.5%
# K = 85: # predicted as positive: 624, # actually positive: 327, accuracy of positive predictions: 52.4%
# K = 86: # predicted as positive: 586, # actually positive: 302, accuracy of positive predictions: 51.5%
# K = 87: # predicted as positive: 624, # actually positive: 327, accuracy of positive predictions: 52.4%
# K = 88: # predicted as positive: 624, # actually positive: 327, accuracy of positive predictions: 52.4%
# K = 89: # predicted as positive: 624, # actually positive: 327, accuracy of positive predictions: 52.4%
# K = 90: # predicted as positive: 534, # actually positive: 279, accuracy of positive predictions: 52.2%
# K = 91: # predicted as positive: 572, # actually positive: 304, accuracy of positive predictions: 53.1%
# K = 92: # predicted as positive: 530, # actually positive: 285, accuracy of positive predictions: 53.8%
# K = 93: # predicted as positive: 530, # actually positive: 285, accuracy of positive predictions: 53.8%
# K = 94: # predicted as positive: 478, # actually positive: 262, accuracy of positive predictions: 54.8%
# K = 95: # predicted as positive: 496, # actually positive: 268, accuracy of positive predictions: 54.0%
# K = 96: # predicted as positive: 496, # actually positive: 268, accuracy of positive predictions: 54.0%
# K = 97: # predicted as positive: 530, # actually positive: 285, accuracy of positive predictions: 53.8%
# K = 98: # predicted as positive: 487, # actually positive: 264, accuracy of positive predictions: 54.2%
# K = 99: # predicted as positive: 530, # actually positive: 285, accuracy of positive predictions: 53.8%
# K = 100: # predicted as positive: 441, # actually positive: 236, accuracy of positive predictions: 53.5%
# K = 101: # predicted as positive: 530, # actually positive: 285, accuracy of positive predictions: 53.8%
# K = 102: # predicted as positive: 407, # actually positive: 219, accuracy of positive predictions: 53.8%
# K = 103: # predicted as positive: 496, # actually positive: 268, accuracy of positive predictions: 54.0%
# K = 104: # predicted as positive: 453, # actually positive: 247, accuracy of positive predictions: 54.5%
# K = 105: # predicted as positive: 530, # actually positive: 285, accuracy of positive predictions: 53.8%
# K = 106: # predicted as positive: 442, # actually positive: 236, accuracy of positive predictions: 53.4%
# K = 107: # predicted as positive: 454, # actually positive: 242, accuracy of positive predictions: 53.3%
# K = 108: # predicted as positive: 416, # actually positive: 217, accuracy of positive predictions: 52.2%
# K = 109: # predicted as positive: 470, # actually positive: 249, accuracy of positive predictions: 53.0%
# K = 110: # predicted as positive: 470, # actually positive: 249, accuracy of positive predictions: 53.0%
# K = 111: # predicted as positive: 492, # actually positive: 260, accuracy of positive predictions: 52.8%
# K = 112: # predicted as positive: 492, # actually positive: 260, accuracy of positive predictions: 52.8%
# K = 113: # predicted as positive: 492, # actually positive: 260, accuracy of positive predictions: 52.8%
# K = 114: # predicted as positive: 436, # actually positive: 232, accuracy of positive predictions: 53.2%
# K = 115: # predicted as positive: 560, # actually positive: 297, accuracy of positive predictions: 53.0%
# K = 116: # predicted as positive: 510, # actually positive: 266, accuracy of positive predictions: 52.2%
# K = 117: # predicted as positive: 573, # actually positive: 303, accuracy of positive predictions: 52.9%
# K = 118: # predicted as positive: 442, # actually positive: 236, accuracy of positive predictions: 53.4%
# K = 119: # predicted as positive: 607, # actually positive: 320, accuracy of positive predictions: 52.7%
# K = 120: # predicted as positive: 585, # actually positive: 309, accuracy of positive predictions: 52.8%
# K = 121: # predicted as positive: 627, # actually positive: 328, accuracy of positive predictions: 52.3%
# K = 122: # predicted as positive: 627, # actually positive: 328, accuracy of positive predictions: 52.3%
# K = 123: # predicted as positive: 627, # actually positive: 328, accuracy of positive predictions: 52.3%
# K = 124: # predicted as positive: 555, # actually positive: 299, accuracy of positive predictions: 53.9%
# K = 125: # predicted as positive: 555, # actually positive: 299, accuracy of positive predictions: 53.9%
# K = 126: # predicted as positive: 521, # actually positive: 282, accuracy of positive predictions: 54.1%
# K = 127: # predicted as positive: 555, # actually positive: 299, accuracy of positive predictions: 53.9%
# K = 128: # predicted as positive: 451, # actually positive: 253, accuracy of positive predictions: 56.1%
# K = 129: # predicted as positive: 476, # actually positive: 265, accuracy of positive predictions: 55.7%
# K = 130: # predicted as positive: 431, # actually positive: 245, accuracy of positive predictions: 56.8%
# K = 131: # predicted as positive: 483, # actually positive: 268, accuracy of positive predictions: 55.5%
# K = 132: # predicted as positive: 465, # actually positive: 262, accuracy of positive predictions: 56.3%
# K = 133: # predicted as positive: 507, # actually positive: 281, accuracy of positive predictions: 55.4%
# K = 134: # predicted as positive: 388, # actually positive: 224, accuracy of positive predictions: 57.7%
# K = 135: # predicted as positive: 474, # actually positive: 264, accuracy of positive predictions: 55.7%
# K = 136: # predicted as positive: 388, # actually positive: 224, accuracy of positive predictions: 57.7%
# K = 137: # predicted as positive: 483, # actually positive: 265, accuracy of positive predictions: 54.9%
# K = 138: # predicted as positive: 406, # actually positive: 230, accuracy of positive predictions: 56.7%
# K = 139: # predicted as positive: 458, # actually positive: 253, accuracy of positive predictions: 55.2%
# K = 140: # predicted as positive: 388, # actually positive: 224, accuracy of positive predictions: 57.7%
# K = 141: # predicted as positive: 440, # actually positive: 247, accuracy of positive predictions: 56.1%
# K = 142: # predicted as positive: 406, # actually positive: 230, accuracy of positive predictions: 56.7%
# K = 143: # predicted as positive: 492, # actually positive: 270, accuracy of positive predictions: 54.9%
# K = 144: # predicted as positive: 474, # actually positive: 264, accuracy of positive predictions: 55.7%
# K = 145: # predicted as positive: 492, # actually positive: 270, accuracy of positive predictions: 54.9%
# K = 146: # predicted as positive: 440, # actually positive: 247, accuracy of positive predictions: 56.1%
# K = 147: # predicted as positive: 492, # actually positive: 270, accuracy of positive predictions: 54.9%
# K = 148: # predicted as positive: 458, # actually positive: 253, accuracy of positive predictions: 55.2%
# K = 149: # predicted as positive: 458, # actually positive: 253, accuracy of positive predictions: 55.2%
# K = 150: # predicted as positive: 458, # actually positive: 253, accuracy of positive predictions: 55.2%
# K = 151: # predicted as positive: 458, # actually positive: 253, accuracy of positive predictions: 55.2%
# K = 152: # predicted as positive: 440, # actually positive: 247, accuracy of positive predictions: 56.1%
# K = 153: # predicted as positive: 458, # actually positive: 253, accuracy of positive predictions: 55.2%
# K = 154: # predicted as positive: 440, # actually positive: 247, accuracy of positive predictions: 56.1%
# K = 155: # predicted as positive: 458, # actually positive: 253, accuracy of positive predictions: 55.2%
# K = 156: # predicted as positive: 402, # actually positive: 222, accuracy of positive predictions: 55.2%
# K = 157: # predicted as positive: 483, # actually positive: 268, accuracy of positive predictions: 55.5%
# K = 158: # predicted as positive: 440, # actually positive: 247, accuracy of positive predictions: 56.1%
# K = 159: # predicted as positive: 504, # actually positive: 275, accuracy of positive predictions: 54.6%
# K = 160: # predicted as positive: 443, # actually positive: 248, accuracy of positive predictions: 56.0%
# K = 161: # predicted as positive: 461, # actually positive: 254, accuracy of positive predictions: 55.1%
# K = 162: # predicted as positive: 461, # actually positive: 254, accuracy of positive predictions: 55.1%
# K = 163: # predicted as positive: 483, # actually positive: 265, accuracy of positive predictions: 54.9%
# K = 164: # predicted as positive: 391, # actually positive: 225, accuracy of positive predictions: 57.5%
# K = 165: # predicted as positive: 489, # actually positive: 265, accuracy of positive predictions: 54.2%
# K = 166: # predicted as positive: 413, # actually positive: 236, accuracy of positive predictions: 57.1%
# K = 167: # predicted as positive: 526, # actually positive: 286, accuracy of positive predictions: 54.4%
# K = 168: # predicted as positive: 418, # actually positive: 222, accuracy of positive predictions: 53.1%
# K = 169: # predicted as positive: 418, # actually positive: 222, accuracy of positive predictions: 53.1%
# K = 170: # predicted as positive: 400, # actually positive: 216, accuracy of positive predictions: 54.0%
# K = 171: # predicted as positive: 465, # actually positive: 259, accuracy of positive predictions: 55.7%
# K = 172: # predicted as positive: 443, # actually positive: 248, accuracy of positive predictions: 56.0%
# K = 173: # predicted as positive: 455, # actually positive: 245, accuracy of positive predictions: 53.8%
# K = 174: # predicted as positive: 416, # actually positive: 230, accuracy of positive predictions: 55.3%
# K = 175: # predicted as positive: 493, # actually positive: 270, accuracy of positive predictions: 54.8%
# K = 176: # predicted as positive: 405, # actually positive: 223, accuracy of positive predictions: 55.1%
# K = 177: # predicted as positive: 493, # actually positive: 270, accuracy of positive predictions: 54.8%
# K = 178: # predicted as positive: 427, # actually positive: 234, accuracy of positive predictions: 54.8%
# K = 179: # predicted as positive: 405, # actually positive: 223, accuracy of positive predictions: 55.1%
# K = 180: # predicted as positive: 405, # actually positive: 223, accuracy of positive predictions: 55.1%
# K = 181: # predicted as positive: 476, # actually positive: 255, accuracy of positive predictions: 53.6%
# K = 182: # predicted as positive: 493, # actually positive: 270, accuracy of positive predictions: 54.8%
# K = 183: # predicted as positive: 471, # actually positive: 259, accuracy of positive predictions: 55.0%
# K = 184: # predicted as positive: 324, # actually positive: 173, accuracy of positive predictions: 53.4%
# K = 185: # predicted as positive: 427, # actually positive: 234, accuracy of positive predictions: 54.8%
# K = 186: # predicted as positive: 346, # actually positive: 184, accuracy of positive predictions: 53.2%
# K = 187: # predicted as positive: 346, # actually positive: 184, accuracy of positive predictions: 53.2%
# K = 188: # predicted as positive: 346, # actually positive: 184, accuracy of positive predictions: 53.2%
# K = 189: # predicted as positive: 388, # actually positive: 203, accuracy of positive predictions: 52.3%
# K = 190: # predicted as positive: 388, # actually positive: 203, accuracy of positive predictions: 52.3%
# K = 191: # predicted as positive: 415, # actually positive: 221, accuracy of positive predictions: 53.3%
# K = 192: # predicted as positive: 388, # actually positive: 203, accuracy of positive predictions: 52.3%
# K = 193: # predicted as positive: 388, # actually positive: 203, accuracy of positive predictions: 52.3%
# K = 194: # predicted as positive: 388, # actually positive: 203, accuracy of positive predictions: 52.3%
# K = 195: # predicted as positive: 469, # actually positive: 253, accuracy of positive predictions: 53.9%
# K = 196: # predicted as positive: 399, # actually positive: 212, accuracy of positive predictions: 53.1%
# K = 197: # predicted as positive: 442, # actually positive: 235, accuracy of positive predictions: 53.2%
# K = 198: # predicted as positive: 442, # actually positive: 235, accuracy of positive predictions: 53.2%
# K = 199: # predicted as positive: 442, # actually positive: 233, accuracy of positive predictions: 52.7%

# %%
knn134 = KNeighborsClassifier(n_neighbors=134)
knn134.fit(x_train,y_train)
knn134_pred = knn134.predict(x_test)
confusion_table(knn134_pred,y_test)
# Out:
# Truth        0    1
# Predicted
# 0          550  312
# 1          164  224

# %%
np.mean(knn134_pred==y_test)
# Out:
# 0.6192

# %%
train_model_3 = MS(["AI_Personalization_Effectiveness", "Satisfaction_with_AI_Services","Change_in_Usage_Patterns"]).fit(train)
test_model_3 = MS(["AI_Personalization_Effectiveness", "Satisfaction_with_AI_Services","Change_in_Usage_Patterns"]).fit(test)
x_train_3 = train_model_3.transform(train)
x_test_3 = test_model_3.transform(test)
y_train_3 = train["Customer_Churn"]
y_test_3 = test["Customer_Churn"]

x_train_3, x_test_3 = [M.drop(columns=['intercept']) for M in [x_train_3,x_test_3]]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Initialize a dictionary to store accuracy for each K
accuracy_for_each_k = {}

for K in range(1, 400):
    knn = KNeighborsClassifier(n_neighbors=K)
    knn.fit(x_train_3, y_train_3)
    knn_pred_3 = knn.predict(x_test_3)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_test_3, knn_pred_3)
    
    # Store accuracy in the dictionary with K as the key
    accuracy_for_each_k[K] = accuracy

# Find the K with the highest accuracy
best_K = max(accuracy_for_each_k, key=accuracy_for_each_k.get)
best_accuracy = accuracy_for_each_k[best_K]

print(f"The best K is {best_K} with an accuracy of {best_accuracy:.2%}")
# Out:
# The best K is 136 with an accuracy of 59.92%

# %%
logit = LogisticRegression(C=1e10,solver='liblinear')
logit.fit(x_train,y_train)
logit_prob = logit.predict_proba(x_test)
logit_labels = np.where(logit_prob[:,1] > 0.475, 1, 0)

confusion_table(logit_labels,y_test)
# Out:
# Truth        0    1
# Predicted
# 0          553  372
# 1          161  164

# %%
accuracy = accuracy_score(y_test, logit_labels)
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 57.36%

# %%
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization strength
    'penalty': ['l1', 'l2'],  # Type of regularization
    'solver': ['liblinear']  # Algorithm to use in the optimization problem
}
grid_search = GridSearchCV(LogisticRegression(), param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)
grid_search.fit(x_train, y_train)
# Best parameter set found
print("Best parameters found: ", grid_search.best_params_)

# Best score
print("Best score: ", grid_search.best_score_)

# Best estimator (model)
best_model = grid_search.best_estimator_

# You can now use best_model to make predictions
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best parameters found:  {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# Best score:  0.5833999999999999

# %%
logit_new = LogisticRegression(C=0.1,solver='liblinear',penalty='l2')
logit_new.fit(x_train,y_train)
logit_prob_new = logit_new.predict_proba(x_test)
logit_labels_new = np.where(logit_prob_new[:,1] > 0.45, 1, 0)
accuracy = accuracy_score(y_test, logit_labels_new)
print(f"Accuracy: {accuracy:.2%}")
confusion_table(logit_labels_new,y_test)
# Out:
# Accuracy: 59.04%
# Truth        0    1
# Predicted
# 0          496  294
# 1          218  242
